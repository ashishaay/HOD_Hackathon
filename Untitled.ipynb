# %%
import pandas as pd

# %%
df = pd.read_parquet("D:\\hackathon_HOD\\GDSC Dataset\\training_data\\train1.parquet")

# %%
df
# Out:
#                     security_product_name machine_version      app_version  \
# __null_dask_index__
# 0                            win8defender     1.1.15100.1  4.18.1807.18075
# 0                            win8defender     1.1.15200.1  4.18.1807.18075
# 0                            win8defender     1.1.15200.1  4.18.1807.18075
# 0                            win8defender     1.1.13804.0       4.10.209.0
# 0                            win8defender     1.1.15100.1     4.10.14393.0
# ...                                   ...             ...              ...
# 131225                       win8defender     1.1.15200.1  4.18.1807.18075
# 131226                       win8defender     1.1.15100.1  4.18.1807.18075
# 131227                       win8defender     1.1.15100.1  4.18.1806.18062
# 131228                       win8defender     1.1.15100.1  4.18.1807.18075
# 131230                       win8defender     1.1.15100.1  4.18.1806.18062
#
# ...
