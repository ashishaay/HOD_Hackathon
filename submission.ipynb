# %%
import pandas as pd

# %%
df = pd.read_parquet(r'D:\hackathon_HOD\final_test.parquet')
df.head()
# Out:
#             app_version  av_sig_version  is_beta  rtp_state  is_sxs_passive  \
# machine_id
# 2                    55            7374        0        7.0               0
# 5                    49            7152        0        5.0               0
# 6                    43            6722        0        7.0               0
# 8                    55            7506        0        7.0               0
# 9                    19            7394        0        7.0               0
#
#             av_status  av_prod_installed  processor  os_build  os_suite  ...  \
# machine_id                                                               ...
# 2             53447.0                1.0          2     16299       768  ...
# 5             55254.0                2.0          1     16299       256  ...
# 6             53447.0                1.0          2     16299       256  ...
# 8             53447.0                1.0          1     17134       256  ...
# ...
