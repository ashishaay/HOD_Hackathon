# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\hackathon_HOD\GDSC Dataset\kaggle_original_test.csv")
# Out:
# C:\Users\udain\AppData\Local\Temp\ipykernel_24204\3060737798.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("D:\hackathon_HOD\GDSC Dataset\kaggle_original_test.csv")

# %%
cols_drop = ['default_browser', 'pua_mode', 'processor_class', 'battery_type',
       'flighting_status', 'threshold_choice', 'wim_boot_status']

df.drop(cols_drop, axis =1, inplace=True)

# %%
object_col_list=[]
for i in df.columns:
    if df[i].dtype==object:
        object_col_list.append(i)
len(object_col_list)
# Out:
# 27

# %%
l_encoder = preprocessing.LabelEncoder()

for element in object_col_list:
    df[element] = l_encoder.fit_transform(df[element])

# %%
df.isna().sum()
# Out:
# machine_id                    0
# security_product_name         0
# machine_version               0
# app_version                   0
# av_sig_version                0
#                           ...
# aoac_support              31429
# is_gamer                 132797
# region_id                132797
# age                           0
# sex                           0
# Length: 77, dtype: int64

# %%
df.drop(['age','sex'], inplace=True, axis = 1)

# %%
df.set_index(['machine_id'], inplace=True)

# %%
for i in df.columns:
  if df[i].isna().sum()>0:
    df[i].fillna(df[i].mode()[0],inplace=True)
df.head()
# Out:
#             security_product_name  machine_version  app_version  \
# machine_id
# 5000000                         4               44            0
# 5000001                         4               61           56
# 5000002                         4               62           90
# 5000003                         4               61            0
# 5000004                         4               62           56
#
#             av_sig_version  is_beta  rtp_state  is_sxs_passive  av_status  \
# machine_id
# 5000000               4532        0        7.0               0    40645.0
# 5000001               7467        0        7.0               0    53447.0
# 5000002               8245        0        7.0               0    53447.0
# 5000003               7765        0        7.0               0    52652.0
# 5000004               8114        0        7.0               0    53447.0
#
#             av_prod_installed  av_prod_enabled  ...  flight_ring  \
# machine_id                                      ...
# 5000000                   3.0              1.0  ...            4
# 5000001                   1.0              1.0  ...            4
# 5000002                   1.0              1.0  ...            4
# 5000003                   2.0              1.0  ...            4
# 5000004                   1.0              1.0  ...            4
#
#             firmware_manufacturer_id  firmware_version_id  secure_boot_status  \
# machine_id
# 5000000                        142.0              62171.0                   0
# 5000001                         93.0              17602.0                   1
# 5000002                        142.0              69820.0                   0
# 5000003                        628.0              19198.0                   1
# 5000004                        628.0              41264.0                   0
#
#             virtual_dev_status  touch_support  pen_support  aoac_support  \
# machine_id
# 5000000                    0.0              0            0           0.0
# 5000001                    0.0              1            0           0.0
# 5000002                    0.0              0            0           0.0
# 5000003                    0.0              0            0           0.0
# 5000004                    0.0              0            0           0.0
#
#             is_gamer  region_id
# machine_id
# 5000000          1.0        7.0
# 5000001          1.0        1.0
# 5000002          1.0       11.0
# 5000003          0.0       11.0
# 5000004          0.0       10.0
#
# [5 rows x 74 columns]

# %%
print(df.isna().sum().sum())
# Out:
# 0

# %%
new_df =  df
new_df.to_parquet("new_test.parquet")

# %%
final_drop = ['security_product_name', 'install_language_identifier', 'state_name',
       'city_id', 'flight_ring', 'uac_luaenable', 'org_id', 'auto_update_opt',
       'branch', 'firmware_version_id', 'model_id.1', 'geo_id',
       'country_id', 'ui_locale_identifier', 'av_prod_enabled',
       'display_resolution_vertical', 'app_version', 'firewall', 'model_id',
       'sku_edition', 'system_volume_capacity', 'manufacturer_id',
       'os_suite', 'chassis_type', 'os_build', 'display_resolution_horizontal',
       'rtp_state', 'os_ptfm_sub_release', 'mdc2_form_factor',
       'install_type_name', 'av_sig_version', 'ie_ver_id', 'machine_version',
       'os_build_lab']

# %%
df.drop(final_drop, axis=1, inplace=True)

# %%
df
# Out:
#             is_beta  is_sxs_passive  av_status  av_prod_installed  has_tpm  \
# machine_id
# 5000000           0               0    40645.0                3.0        1
# 5000001           0               0    53447.0                1.0        1
# 5000002           0               0    53447.0                1.0        1
# 5000003           0               0    52652.0                2.0        1
# 5000004           0               0    53447.0                1.0        1
# ...             ...             ...        ...                ...      ...
# 8921478           0               0    53447.0                1.0        1
# 8921479           0               0    53447.0                1.0        1
# 8921480           0               0    53447.0                1.0        1
# 8921481           0               0    43927.0                2.0        1
# 8921482           0               0    53447.0                1.0        1
#
#             local_name_id  platform  processor  os_version  is_protected  ...  \
# machine_id                                                                ...
# 5000000                42         0          1           0           1.0  ...
# 5000001                74         0          1           0           1.0  ...
# 5000002                75         0          2           0           1.0  ...
# 5000003               113         0          1           0           1.0  ...
# 5000004                75         0          1           0           1.0  ...
# ...                   ...       ...        ...         ...           ...  ...
# 8921478               170         0          1           0           1.0  ...
# 8921479                88         0          1           0           1.0  ...
# 8921480                46         0          2           0           1.0  ...
# 8921481               115         0          1           0           1.0  ...
# 8921482               231         0          1           0           1.0  ...
#
#             activation_channel  flights_activity  firmware_manufacturer_id  \
# machine_id
# 5000000                      2               0.0                     142.0
# 5000001                      2               0.0                      93.0
# 5000002                      2               0.0                     142.0
# 5000003                      2               0.0                     628.0
# 5000004                      2               0.0                     628.0
# ...                        ...               ...                       ...
# 8921478                      2               0.0                     355.0
# 8921479                      0               0.0                     513.0
# 8921480                      2               0.0                     142.0
# 8921481                      1               0.0                     142.0
# 8921482                      0               0.0                     628.0
#
#             secure_boot_status  virtual_dev_status  touch_support  \
# machine_id
# 5000000                      0                 0.0              0
# 5000001                      1                 0.0              1
# 5000002                      0                 0.0              0
# 5000003                      1                 0.0              0
# 5000004                      0                 0.0              0
# ...                        ...                 ...            ...
# 8921478                      0                 0.0              0
# 8921479                      0                 0.0              1
# 8921480                      0                 0.0              0
# 8921481                      0                 0.0              0
# 8921482                      1                 0.0              0
#
#             pen_support  aoac_support  is_gamer  region_id
# machine_id
# 5000000               0           0.0       1.0        7.0
# 5000001               0           0.0       1.0        1.0
# 5000002               0           0.0       1.0       11.0
# 5000003               0           0.0       0.0       11.0
# 5000004               0           0.0       0.0       10.0
# ...                 ...           ...       ...        ...
# 8921478               0           0.0       0.0       10.0
# 8921479               0           1.0       0.0        5.0
# 8921480               0           0.0       0.0        7.0
# 8921481               0           0.0       0.0        3.0
# 8921482               0           0.0       0.0       10.0
#
# [3921483 rows x 40 columns]

# %%
df.to_parquet('Clean_test.parquet')
